# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pymongo

sns.set(style='ticks')
client = pymongo.MongoClient("mongodb+srv://admin:admin@cluster0-8vzpx.gcp.mongodb.net/test?retryWrites=true&w=majority")
database = client.unemployment_data
homeless1 = database.homeless1
homeless2 = database.homeless2

# %%
homeless1_data = pd.DataFrame(list(homeless1.find()))
homeless2_data = pd.DataFrame(list(homeless2.find()))

# %%
# homeless1_data.insert(0, 'id', range(0, len(homeless1_data)))
# homeless2_data.insert(0, 'id', range(0, len(homeless2_data)))

# %%
# homeless1_data = homeless1_data.drop('index', axis=1)
homeless1_data
# Out:
#         id                       _id CoC Number  \
# 0        0  5e52b003ef313cd4b609cf81     AK-500
# 1        1  5e52b003ef313cd4b609cf82     AK-501
# 2        2  5e52b003ef313cd4b609cf83     AL-500
# 3        3  5e52b003ef313cd4b609cf84     AL-501
# 4        4  5e52b003ef313cd4b609cf85     AL-502
# ...    ...                       ...        ...
# 1003  1003  5e52b003ef313cd4b609d378     MI-512
# 1004  1004  5e52b003ef313cd4b609d379     MI-513
# 1005  1005  5e52b003ef313cd4b609d37a     MI-514
# 1006  1006  5e52b003ef313cd4b609d37b     MI-515
# 1007  1007  5e52b003ef313cd4b609d37c     MI-516
#
#                                                CoC Name  \
# 0                                         Anchorage CoC
# 1                           Alaska Balance of State CoC
# 2     Birmingham/Jefferson St. Clair Shelby Counties...
# 3               Mobile City & County/Baldwin County CoC
# 4                        Florence/Northwest Alabama CoC
# ...

# %%
# homeless2_data = homeless2_data.drop('ida', axis=1)
homeless2_data
# Out:
#       id                       _id CoC Number  \
# 0      0  5e52b068ef313cd4b60a1494     MI-518
# 1      1  5e52b068ef313cd4b60a1495     MI-519
# 2      2  5e52b068ef313cd4b60a1496     MI-523
# 3      3  5e52b068ef313cd4b60a1497     MN-500
# 4      4  5e52b068ef313cd4b60a1498     MN-501
# ..   ...                       ...        ...
# 994  994  5e52b068ef313cd4b60a187f     WV-503
# 995  995  5e52b068ef313cd4b60a1880     WV-508
# 996  996  5e52b068ef313cd4b60a1881     WY-500
# 997  997  5e52b068ef313cd4b60a1882
# 998  998  5e52b068ef313cd4b60a1883
#
#                                               CoC Name CoC Category  \
# 0                                Livingston County CoC          103
# 1                            Holland/Ottawa County CoC          258
# 2                                     Eaton County CoC          107
# 3                      Minneapolis/Hennepin County CoC         3057
# 4                         Saint Paul/Ramsey County CoC         1438
# ...

# %%
homeless1_data.dtypes
# Out:
# id                                                                    int64
# _id                                                                  object
# CoC Number                                                           object
# CoC Name                                                             object
# CoC Category                                                         object
# Overall Homeless 2019                                                object
# Overall Homeless - Under 18 2019                                     object
# Overall Homeless - Age 18 to 24 2019                                 object
# Overall Homeless - Over 24 2019                                      object
# Overall Homeless - Female 2019                                       object
# Overall Homeless - Male 2019                                         object
# Overall Homeless - Transgender 2019                                  object
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-788206b416fb> in <module>
# ----> 1 homeless1_data['Overall Homeless 2019'].astype(int)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
# ...
