# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pymongo
import datetime

# %%
sns.set(color_codes=True)
# tips = sns.load_dataset("tips")

# %%
CONNECTION_STRING = "mongodb+srv://admin:admin@cluster0-8vzpx.gcp.mongodb.net/test?retryWrites=true&w=majority"
client = pymongo.MongoClient(CONNECTION_STRING)
unemployment_data = client.get_database('unemployment_data')

# %%
unemployment_rate = unemployment_data.get_collection('unemployment_rate')
df_unemployment_rate = pd.DataFrame(list(unemployment_rate.find()))
df_unemployment_rate['date'] = df_unemployment_rate['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment", data=df_unemployment_rate)

# %%
unemployment_asian = unemployment_data.get_collection('unemployment_asian')
df_unemployment_asian = pd.DataFrame(list(unemployment_asian.find()))
df_unemployment_asian['date'] = df_unemployment_asian['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment_asian", data=df_unemployment_asian)

# %%
unemployment_bachelors = unemployment_data.get_collection('unemployment_bachelors')
df_unemployment_bachelors = pd.DataFrame(list(unemployment_bachelors.find()))
df_unemployment_bachelors['date'] = df_unemployment_bachelors['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment_bachelors", data=df_unemployment_bachelors)

# %%
unemployment_black = unemployment_data.get_collection('unemployment_black')
df_unemployment_black = pd.DataFrame(list(unemployment_black.find()))
df_unemployment_black['date'] = df_unemployment_black['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment_black", data=df_unemployment_black)

# %%
unemployment_highschool = unemployment_data.get_collection('unemployment_highschool')
df_unemployment_highschool = pd.DataFrame(list(unemployment_highschool.find()))
df_unemployment_highschool['date'] = df_unemployment_highschool['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment_highschool", data=df_unemployment_highschool)

# %%
unemployment_latino = unemployment_data.get_collection('unemployment_latino')
df_unemployment_latino = pd.DataFrame(list(unemployment_latino.find()))
df_unemployment_latino['date'] = df_unemployment_latino['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment_latino", data=df_unemployment_latino)

# %%
unemployment_men = unemployment_data.get_collection('unemployment_men')
df_unemployment_men = pd.DataFrame(list(unemployment_men.find()))
df_unemployment_men['date'] = df_unemployment_men['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment_men", data=df_unemployment_men)

# %%
unemployment_white = unemployment_data.get_collection('unemployment_white')
df_unemployment_white = pd.DataFrame(list(unemployment_white.find()))
df_unemployment_white['date'] = df_unemployment_white['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment_white", data=df_unemployment_white)

# %%
unemployment_women = unemployment_data.get_collection('unemployment_women')
df_unemployment_women = pd.DataFrame(list(unemployment_women.find()))
df_unemployment_women['date'] = df_unemployment_women['date'].astype('datetime64[ns]')
sns.relplot(x="date", y="unemployment_women", data=df_unemployment_women, kind='line')
