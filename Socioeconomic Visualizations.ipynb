# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pymongo

sns.set(style='ticks')
client = pymongo.MongoClient("mongodb+srv://admin:admin@cluster0-8vzpx.gcp.mongodb.net/test?retryWrites=true&w=majority")
database = client.unemployment_data
SE = database.socioeconomic_data
SE_data = pd.DataFrame(list(SE.find()))

# %%
dtypes = SE_data.dtypes
print(dtypes)
int_columns = SE_data.select_dtypes(include=['int64'])
print(int_columns)
# Out:
# _id                           object
# par_pctile                     int64
# count_pooled                   int64
# count_aian_pooled              int64
# count_asian_pooled             int64
#                               ...
# kir_par_nohome_white_male    float64
# spouse_rank_black_female     float64
# spouse_rank_black_male       float64
# spouse_rank_white_female     float64
# spouse_rank_white_male       float64
# Length: 70, dtype: object
#     par_pctile  count_pooled  count_aian_pooled  count_asian_pooled  \
# 0            1        213100               3300                9100
# 1            2        213100               3000                8900
# 2            3        213100               2900                8900
# 3            4        213100               2800                8900
# 4            5        213100               2900                8900
# ..         ...           ...                ...                 ...
# ...

# %%
# SE_melt_data = SE_data.melt('par_pctile', var_name='cols', value_name='vals')
# SE_catplot_data = sns.factorplot(x='par_pctile', y='vals', hue='cols', data=SE_melt_data)

# %%
sns.relplot(x='par_pctile', y='count_aian_pooled', data=SE_data)
sns.relplot(x='par_pctile', y='count_asian_pooled', data=SE_data)
sns.relplot(x='par_pctile', y='count_white_pooled', data=SE_data)

# %%
sns.lmplot(x='par_pctile', y='count_black_pooled', data=SE_data)
sns.lmplot(x='par_pctile', y='count_hisp_pooled', data=SE_data)

# %%
float_columns = SE_data.select_dtypes(include=['float64'])
print(float_columns)
# Out:
#     kfr_aian_pooled  kfr_asian_pooled  kfr_black_female  kfr_black_male  \
# 0             23.80             51.71             27.81           22.55
# 1             25.51             52.45             28.57           23.35
# 2             26.19             52.24             29.31           24.18
# 3             26.71             52.43             29.76           24.69
# 4             27.22             53.29             30.19           25.29
# ..              ...               ...               ...             ...
# 95            58.38             71.77             58.08           54.27
# 96            56.28             72.28             60.06           54.70
# 97            60.38             72.77             60.88           56.04
# 98            61.68             74.19             61.68           56.34
# 99            62.92             77.56             63.66           59.59
#
#     kfr_black_pooled  kfr_hisp_pooled  kfr_nativemom_aian_pooled  \
# ...

# %%
sns.relplot(x='par_pctile', y='kfr_aian_pooled', data=SE_data)
sns.relplot(x='par_pctile', y='kfr_asian_pooled', data=SE_data)
sns.relplot(x='par_pctile', y='kfr_white_pooled', data=SE_data)

# %%
sns.relplot(x='par_pctile', y='kfr_black_pooled', data=SE_data)
sns.relplot(x='par_pctile', y='kfr_hisp_pooled', data=SE_data)
